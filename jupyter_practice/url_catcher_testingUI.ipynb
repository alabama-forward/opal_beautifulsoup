# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import time

# %%
def get_all_news_urls(base_url, suffix:str, max_pages:int=None):
    news_urls = []
    page = 1
    continue_search = True
    
    try:
        while continue_search:
            if page == 1:
                current_url = base_url
            else:
                current_url = f"{base_url}/page/{page}"
            
            headers = {
                'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36',
                'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8'
            }
            
            response = requests.get(current_url, headers=headers)
            
            if response.status_code != 200:
                print(f"Reached end at page {page-1}")
                break
                
            soup = BeautifulSoup(response.text, 'html.parser')
            links = soup.find_all('a')
            
            found_on_page = 0
            
            for link in links:
                href = link.get('href')
                if href:
                    full_url = urljoin(current_url, href)
                    if suffix in full_url:
                        if full_url not in news_urls:
                            news_urls.append(str(full_url))
                            found_on_page += 1
            
            print(f"Page {page}: Found {found_on_page} new URLs")
            
            # Check max_pages condition
            if max_pages is not None and page >= max_pages:  # Modified this condition
                print(f"Reached maximum pages limit: {max_pages}")
                break
            if found_on_page == 0:
                print("No new URLs found on this page")
                break
                
            page += 1
            time.sleep(1)
            
        return news_urls
        
    except requests.RequestException as e:
        print(f"Error: {e}")
        return news_urls

def main(base_url:str, suffix:str, max_pages:int=None):
    print(f"In main(), max_pages = {max_pages}")  # Debug print
    urls = get_all_news_urls(base_url, suffix, max_pages=max_pages)  # Explicitly named parameter
    
    print("\nResults Summary:")
    print(f"Total URLs found: {len(urls)}")
    print("\nAll URLs:")
    print(urls)
    for url in urls[:max_pages]:
        print(url)

if __name__ == "__main__":
    main('https://aldailynews.com', '', max_pages=10)
# Out:
# In main(), max_pages = 10
# Page 1: Found 36 new URLs
# Page 2: Found 3 new URLs
# Page 3: Found 3 new URLs
# Page 4: Found 3 new URLs
# Page 5: Found 3 new URLs
# Page 6: Found 3 new URLs
# Page 7: Found 3 new URLs
# Page 8: Found 3 new URLs
# Page 9: Found 3 new URLs
# Page 10: Found 3 new URLs
# Reached maximum pages limit: 10
#
# Results Summary:
# Total URLs found: 63
#
# All URLs:
# ['https://aldailynews.com#daily-news', 'https://aldailynews.com/', 'https://aldailynews.com/login', 'https://aldailynews.com/logout/?redirect_to=https%3A%2F%2Faldailynews.com&_wpnonce=3b2e12d755', 'https://aldailynews.com/membership-account/subscription/', 'https://aldailynews.com/membership-account/', 'https://aldailynews.com/category/inside-alabama-politics/', 'https://aldailynews.com/category/new-member-profiles/', 'https://aldailynews.com/category/commentary/', 'https://aldailynews.com/category/podcasts-and-videos/', 'https://aldailynews.com/category/education/', 'https://aldailynews.com/category/legislature-2025/', 'https://aldailynews.com/category/campaign_2024/', 'https://aldailynews.com', 'https://aldailynews.com/alfa-health-plan-debate-brews-again-in-state-house/', 'https://aldailynews.com/category/featured/', 'https://aldailynews.com/category/news/', 'https://aldailynews.com/author/marysellquillen/', 'https://aldailynews.com/this-week-alabama-house-to-tackle-bills-on-illegal-immigration-crime-and-veterans/', 'https://aldailynews.com/author/awillis/', 'https://aldailynews.com/how-doge-could-impact-nasas-presence-in-huntsville/', 'https://aldailynews.com/author/alex-angle/', 'https://aldailynews.com/federal-workers-confront-mass-confusion-as-musks-deadline-to-list-accomplishments-looms/', 'https://aldailynews.com/trump-putin-summit-preparations-are-underway-russia-says/', 'https://aldailynews.com/column-why-should-i-care-about-a-new-school-funding-system/', 'https://aldailynews.com/new-fbi-director-kash-patel-plans-to-move-up-to-1500-workers-out-of-washington/', 'https://aldailynews.com/youll-be-impressed-public-hearings-planned-to-reveal-progress-in-improving-alabama-government-efficiency/', 'https://aldailynews.com/supreme-court-clears-the-way-for-a-lawsuit-over-covid-19-pandemic-era-unemployment-claims-in-alabama/', 'https://aldailynews.com/capitol-journal-february-21-2025/', 'https://aldailynews.com/news', 'https://aldailynews.com/cdn-cgi/l/email-protection#e5918a8181a5848981848c899c8b809296cb868a88', 'https://aldailynews.com/who-we-are/', 'https://aldailynews.com/contact/', 'https://www.facebook.com/AlabamaDailyNews/', 'https://twitter.com/ALDailyNews', 'https://infomedia.com', 'https://aldailynews.com/page/2#daily-news', 'https://aldailynews.com/page/2', 'https://aldailynews.com/cdn-cgi/l/email-protection#c4b0aba0a084a5a8a0a5ada8bdaaa1b3b7eaa7aba9', 'https://aldailynews.com/page/3#daily-news', 'https://aldailynews.com/page/3', 'https://aldailynews.com/cdn-cgi/l/email-protection#deaab1baba9ebfb2babfb7b2a7b0bba9adf0bdb1b3', 'https://aldailynews.com/page/4#daily-news', 'https://aldailynews.com/page/4', 'https://aldailynews.com/cdn-cgi/l/email-protection#5c283338381c3d30383d35302532392b2f723f3331', 'https://aldailynews.com/page/5#daily-news', 'https://aldailynews.com/page/5', 'https://aldailynews.com/cdn-cgi/l/email-protection#bcc8d3d8d8fcddd0d8ddd5d0c5d2d9cbcf92dfd3d1', 'https://aldailynews.com/page/6#daily-news', 'https://aldailynews.com/page/6', 'https://aldailynews.com/cdn-cgi/l/email-protection#a4d0cbc0c0e4c5c8c0c5cdc8ddcac1d3d78ac7cbc9', 'https://aldailynews.com/page/7#daily-news', 'https://aldailynews.com/page/7', 'https://aldailynews.com/cdn-cgi/l/email-protection#e3978c8787a3828f87828a8f9a8d869490cd808c8e', 'https://aldailynews.com/page/8#daily-news', 'https://aldailynews.com/page/8', 'https://aldailynews.com/cdn-cgi/l/email-protection#8bffe4efefcbeae7efeae2e7f2e5eefcf8a5e8e4e6', 'https://aldailynews.com/page/9#daily-news', 'https://aldailynews.com/page/9', 'https://aldailynews.com/cdn-cgi/l/email-protection#1e6a717a7a5e7f727a7f777267707b696d307d7173', 'https://aldailynews.com/page/10#daily-news', 'https://aldailynews.com/page/10', 'https://aldailynews.com/cdn-cgi/l/email-protection#176378737357767b73767e7b6e797260643974787a']
# https://aldailynews.com#daily-news
# https://aldailynews.com/
# https://aldailynews.com/login
# https://aldailynews.com/logout/?redirect_to=https%3A%2F%2Faldailynews.com&_wpnonce=3b2e12d755
# https://aldailynews.com/membership-account/subscription/
# https://aldailynews.com/membership-account/
# https://aldailynews.com/category/inside-alabama-politics/
# https://aldailynews.com/category/new-member-profiles/
# https://aldailynews.com/category/commentary/
# https://aldailynews.com/category/podcasts-and-videos/
